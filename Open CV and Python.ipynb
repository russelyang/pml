# %% [markdown]
# # OpenCV 101; A practical Guild to the Open Computer Vision Libary
#
# https://www.youtube.com/watch?v=jKtQxvzp1A0

# %%
# %matplotlib inline
# %pylab notebook
import cv2
import numpy as np
from matplotlib import pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
PATH = "clouds.jpg"
image = cv2.imread(PATH)
cv_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
figure()
imshow(cv_rgb)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
image.shape
image[0,0,:]
# Out:
# array([195, 154, 139], dtype=uint8)

# %%
cv_rgb[0,0,:]
# Out:
# array([139, 154, 195], dtype=uint8)

# %% [markdown]
# ## cv2 way of display image

# %%
cv2.imshow('hello', image)
cv2.waitKey()
cv2.destroyWindow('hello')

# %% [markdown]
# # Simple filtering example

# %%
blurred = cv2.GaussianBlur(image, (19,19), 0)
figure()
imshow(blurred)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# PATH       str        clouds.jpg
# blurred    ndarray    384x512x3: 589824 elems, type `uint8`, 589824 bytes (576.0 kb)
# blurred2   ndarray    384x512x3: 589824 elems, type `uint8`, 589824 bytes (576.0 kb)
# cv2        module     <module 'cv2.cv2' from 'e<...>\cv2.cp35-win_amd64.pyd'>
# cv_rgb     ndarray    384x512x3: 589824 elems, type `uint8`, 589824 bytes (576.0 kb)
# image      ndarray    384x512x3: 589824 elems, type `uint8`, 589824 bytes (576.0 kb)
# kernel     ndarray    5x5: 25 elems, type `float32`, 100 bytes

# %%
kernel = np.ones((5,5), np.float32) / 25
blurred2 = cv2.filter2D(image, -1, kernel)
figure()
imshow(blurred)
# Out:
# <img src="data:image/png;base64,..." width="432">
